# %% [markdown]
# ## 한글텍스트 - 분류 모델링
# ### 로지스틱 회귀 모델 with TF-IDF

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import os
import pandas as pd
import numpy as np

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
# 경고메세지 무시
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 데이타 불러오기 - 텍스트 형태

# %%
DATA_IN_PATH = './data_in/' 
DATA_OUT_PATH = './data_out/'
TRAIN_CLEAN_DATA = 'nsmc_train_clean.csv'
TEST_CLEAN_DATA = 'nsmc_test_clean.csv'

RANDOM_SEED = 42
TEST_SPLIT = 0.2

# %%
train_df = pd.read_csv(DATA_IN_PATH + TRAIN_CLEAN_DATA )
test_df = pd.read_csv(DATA_IN_PATH + TEST_CLEAN_DATA )

# %%
train_df.isna().sum().sum()
# Out:
# 1289

# %%
# 결측치 제거
train_df = train_df.dropna()
test_df = test_df.dropna()

# %%
train_df.isna().sum().sum()
# Out:
# 0

# %%
test_df.shape
# Out:
# (49562, 3)

# %% [markdown]
# ### TF-IDF 벡터화
# - min_df : 설정한 값보다 특정 토큰의 df 값이 적게 나오면 벡터화 과정에서 제거한다는 의미
# - max_df : 설정한 값보다 특정 토큰의 df 값이 크게 나오면 벡터화 과정에서 제거한다는 의미
# - ngram_range : 빈도의 기본 단위를 어느 범위의 n-gram으로 설정할 것인지를 지정하는 인자

# %% [markdown]
# #### 형태소 분석기 함수화

# %%
# from konlpy.tag import Okt

# okt = Okt()
# def okt_tokenizer(text):
#     # 입력 인자로 들어온 text 를 형태소 단어로 토큰화 하여 list 객체 반환
#     tokens_ko = okt.morphs(text)
#     return tokens_ko

# Mac 전용 Mecab 사용
from konlpy.tag import Mecab   

mecab = Mecab()
def mecab_tokenizer(text):
    # 입력 인자로 들어온 text 를 형태소 단어로 토큰화 하여 list 객체 반환
    tokens_ko = mecab.morphs(text)
    return tokens_ko

# %%
# okt_tokenizer("꼭 대박나세요")

# Mac 전용 Mecab 사용
mecab_tokenizer("꼭 대박나세요")
# Out:
# ['꼭', '대박', '나세', '요']

# %% [markdown]
# #### TF-IDF 피처벡터화

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Okt 객체의 morphs( ) 객체를 이용한 tokenizer를 사용. ngram_range는 (1,2) 
# tfidf_vect = TfidfVectorizer(tokenizer=okt_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9)

# Mac 전용 Mecab 사용
tfidf_vect = TfidfVectorizer(tokenizer=mecab_tokenizer, ngram_range=(1,2), min_df=3, max_df=0.9)

tfidf_vect.fit(train_df['document'])
tfidf_matrix_train = tfidf_vect.transform(train_df['document'])

# %%
# 단어 행렬 확인(DTM)
tfidf_matrix_train
# Out:
# <148711x108644 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3111333 stored elements in Compressed Sparse Row format>

# %%
print(tfidf_vect.vocabulary_)
# Out:
# ': 38261, '쿨 지': 99968, '여성 라면': 69764, '감독 기억': 1934, '니 그럴': 22891, '고 얕': 7431, '둘 봤': 31313, '재미있 구요': 86979, '밀려오 네요': 44948, '으로 가': 77394, '인 억지': 83096, '정돈 아니': 89308, '게 죽였': 5373, '게 더러운': 4862, '돼냐': 30784, '부리 는데': 49430, '로 는가': 35432, '살아남 았': 52805, '앳킨스': 63697, '개밥 맛': 3319, '싫 습니다': 59297, '에 라': 67382, '같 성격': 2917, '요코': 75374, '지만 아닌': 94260, '그리고 결혼': 12285, '더러웠 다': 28071, '을 와': 79315, '사이코 패스': 52466, '내용 별거': 18656, '삶 순간': 52873, '참 와': 96851, '마리화나': 37780, '재밌 뮤지컬': 87096, '장난치 면': 86421, '딴따라 더': 32712, '독단': 30185, '독단 적': 30186, '스토리 삼류': 57171, '종목': 91489, '만감 교차': 38931, '쿼': 99986, '다 내생': 23662, '적 관심': 87699, '를 정확히': 37180, '등가교환': 32267, '극장판 샴발라': 12663, '연출력 문제': 71048, '끄 영화': 15454, '결과 만': 5775, '케이블 용': 99638, '흐느끼': 108106, '누웠': 21434, '나올까요': 16895, '작품 차라리': 85716, '에겐 최악': 68578, '점수 짜': 89060, '영화 오프닝': 72409, '내 하루': 18324, '엠 블': 69497, '블 런': 50491, '리뷰 안': 37467, '일 뒤': 83937, '엔 제대로': 69382, '존재 며': 91055, '걸 세상': 4435, '만점 이런': 39226, '더 할수록': 27921, '돌려 며': 30444, '수백 대': 56119, '만 맘': 38563, '배우 앙상블': 46590, '치토': 99016, '마사지': 37828, '장면 또': 86524, '열 장면': 71095, '씨 보다': 60301, '실력 과': 59072, '흘르': 108270, '봣어요 ㅋㅋ': 49176, '잼 어용': 87317, '오연수': 73588, '다 씨발': 24230, '안 도와': 62191, '고 고양이': 6381, '끊이 질': 15493, '다가 존나': 25083, '함 반전': 105003, '많이 높': 39508, '짓 야': 95778, '내 욕심': 18221, 'ㅋㅋㅋ 감독': 444, '꺼 란': 14984, '다 숨': 24157, '친근 고': 99086, '연애 라는': 70857, '레딧 카드': 35020, '짙 여운': 95826, '잠수종': 86208, '만국': 38932, '엔 맘': 69320, '중병 같': 92914, '오래 도': 73415, '시네마 에서': 58157, '선물 과': 54272, '느 건지': 21671, '영화 넹': 71772, '번 볼까': 47045, '설레 며': 54394, '와 사람': 74099, '을 맡긴': 78885, '낚일 없': 17160, '배 정도': 46347, '건 절대': 4150, '영화 얼마': 72338, '사춘기 를': 52513, '지 결말': 93243, '에서 피식': 69135, '어요 많': 65466, '해 려는': 105357, '남 구': 17497, '는데 뜬금없이': 22262, '닉 퓨리': 23208, '천재 에': 97520, 'ㅋㅋ 글고': 254, '특이 사람': 101330, '생활 로': 53770, '경 규': 6003, '봐도 놀랍': 48913, '약간 아쉬웠': 63984, '어여 ㅎㅎ': 65381, '영화 된다': 71874, '노르웨이 숲': 20859, '봄 ㅎㅎㅎ': 48780, '하나 라는': 103740, '고 흐뭇': 8242, '가족 스토리': 1424, '학점': 104124, '던 와중': 28314, '의사 선생': 80481, '으로 기부': 77456, '에서 임진강': 69021, '카오스': 99236, '아라 영화': 60947, '대니 보일': 26942, '다소 길': 25744, '애 더': 63246, '경험 었': 6108, '마지막 쫌': 38117, '매우 기대': 40326, '영국 에': 71339, '안겨 줬': 62472, '고 실감': 7314, '어필 고': 65826, '그리고 드라마': 12323, '별점 으로': 47697, '글 래': 12828, '이상 돌려': 82145, '호아킨 피닉스': 106980, '불가 인지': 50164, '역사 고': 70188, '수준 ㄷ': 56212, '다는지 모르': 25351, '급 특유': 13003, '분위기 지만': 50091, '던 알': 28290, '발 한다': 45955, '비젼': 50814, '정령': 89314, '와 로': 74043, '신세계 나': 58978, '이야기 일까': 82388, '인 인도': 83142, '생각 까': 53480, '러라': 34935, '단역 고': 26228, '대본 쓰': 27122, '니 처럼': 23081, '덩크 아류': 28508, '에게 당하': 68450, '에일리언 시리즈': 69228, '떨어지 같': 33278, '서투른': 54185, '메시지 뭔지': 40992, '게 기적': 4731, '모든 인간': 42355, '진국 다': 94840, '갈등 이나': 1769, '사 겨': 51649, '조연 연기력': 90791, '볼 라는': 48651, '그랬 다고': 11924, '욕할 없': 75463, '를 구원': 36498, '부턴가': 49781, '언제 부턴가': 65996, '굿 평점': 10692, '터졌 던': 100739, '꼭 읽': 15215, '액션 나': 63539, '년 상반기': 20680, '으로 장난': 77856, '무척 지': 43699, '기분 업': 13602, '처절 다': 97399, '느껴야 할지': 21696, '자들': 85070, '중 국판': 92711, '를 추': 37275, '사람 맘': 51930, '영화 갖': 71574, '면 ㅈ': 41196, '왜 대단': 74767, '봤 긴': 49198, '을 쳐먹': 79620, '와이프 와': 74362, '도대체 한국': 29992, '가장 고': 1267, '꼭 살': 15195, '옳 다': 73898, '어뜩': 64904, '어뜩 해': 64905, '내내 짠': 18446, '로 셈': 35660, '네요 우연히': 20455, '완전 힐링': 74598, '진짜 소리': 95273, '에 흑': 68408, '지만 ㅠㅠ': 94002, '멋 스럽': 40785, '소리 질르': 55433, '경수': 6040, '감독 궁금': 1927, '의뢰': 80404, '여성 용': 69772, '봣는데 존나': 49164, '다 털': 24813, '그리움 과': 12436, '머나먼 정글': 40562, '눈쌀 찌푸려': 21627, '전설 에': 88310, '일본 진짜': 84190, '어른 라고': 64980, '하 니': 103662, '음 ㅁ': 79864, '탑 건': 100568, '페데리코': 101982, '근데 다시': 12724, '는지 의도': 22731, '명작 시대': 42069, '너무 편하': 19522, '하나하나 모두': 103866, '첫 시작': 97624, '도 애기': 29451, '마틴 프리먼': 38190, '에 언제': 67869, '그나마 좀': 11331, '별로 웃기': 47628, '퀼트': 100022, '에게 비': 68489, '완벽 네요': 74388, '하지만 재미없': 104019, '와 제작진': 7425 ...

# %%
sentence = [train_df['document'][0]]
print(tfidf_vect.transform(sentence).toarray())
# Out:
# [[0. 0. 0. ... 0. 0. 0.]]

# %% [markdown]
# ### 로지스틱 회귀 모델 분류

# %%
# Logistic Regression 을 이용하여 감성 분석 Classification 수행. 
lg_clf = LogisticRegression(random_state=0)

# 모델 학습 - model.fit(x_train, y_train)
lg_clf.fit(tfidf_matrix_train , train_df['label'] )
# Out:
# LogisticRegression(random_state=0)

# %% [markdown]
# ### 테스트 데이타를 이용한 정확도 평가

# %%
from sklearn.metrics import accuracy_score

# 학습 데이터를 적용한 TfidfVectorizer를 이용하여 테스트 데이터를 TF-IDF 값으로 Feature 변환함. 
tfidf_matrix_test = tfidf_vect.transform(test_df['document'])

# 테스트 데이타 예측
preds = lg_clf.predict(tfidf_matrix_test)

print('Logistic Regression 정확도: ',accuracy_score(test_df['label'], preds))
# Out:
# Logistic Regression 정확도:  0.8644122513215771

# %%
# 예측값
pred = lg_clf.predict(tfidf_matrix_test)

# %%
# 실제값
test_df['label']
# Out:
# 0        1
# 2        0
# 3        0
# 4        0
# 5        1
#         ..
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: label, Length: 49562, dtype: int64

# %%
# 정확도
sum(pred == test_df['label'] )
# Out:
# 42842

# %%
42749/49564
# Out:
# 0.8625010087967073

# %% [markdown]
# ### 로지스틱 회귀 모델 분류 & GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# Logistic Regression 을 이용하여 감성 분석 Classification 수행. 
lg_clf = LogisticRegression(random_state=0)

# Parameter C 최적화를 위해 GridSearchCV 를 이용. 
params = { 'C': [1 ,3.5, 4.5, 5.5, 10 ] }
grid_cv = GridSearchCV(lg_clf , param_grid=params , cv=3, scoring='accuracy', verbose=1)
grid_cv.fit(tfidf_matrix_train , train_df['label'] )
print(grid_cv.best_params_ , round(grid_cv.best_score_,4))
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# {'C': 3.5} 0.8645

# %% [markdown]
# ### 테스트 데이타에 TF-IDF 벡터 변환 후 정확도 평가

# %%
from sklearn.metrics import accuracy_score

# 학습 데이터를 적용한 TfidfVectorizer를 이용하여 테스트 데이터를 TF-IDF 값으로 Feature 변환함. 
tfidf_matrix_test = tfidf_vect.transform(test_df['document'])

# classifier 는 GridSearchCV에서 최적 파라미터로 학습된 classifier를 그대로 이용
best_estimator = grid_cv.best_estimator_
preds = best_estimator.predict(tfidf_matrix_test)

print('Logistic Regression 정확도: ',accuracy_score(test_df['label'],preds))
# Out:
# Logistic Regression 정확도:  0.8679431822767443

# %% [markdown]
# # 로지스틱 회귀모델 with Word2Vec
# # 랜덤포레스트 모델 with TF-IDF
# # 랜덤포레스트 모델 with Word2Vec
